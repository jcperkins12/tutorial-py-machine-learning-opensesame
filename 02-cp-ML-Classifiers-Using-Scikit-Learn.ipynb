# %% [markdown]
# # ML with Scikit-Learn
#
# Code following along with the opensesame turorial [python machine learning course](https://player.opensesame.com/coursecontent/e0574515-e184-9194-31e9-355866e13f22/232590/00000000-0000-0000-0000-000000000000/62D4A280;de06e6f7424c2da8eefe20a3a55d1d5039561b361b5dd60e332433627667306c/scormcontent/index.html#/).

# %%
# %load_ext lab_black

# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.colors import ListedColormap

# set the plot figure size
rcParams["figure.figsize"] = 10, 5
# %matplotlib inline

# %% [markdown]
# ## Training a perceptron via scikit-learn

# %%
# load the iris dataset from sklearn
iris = datasets.load_iris()

# separate features and targets
X = iris.data
y = iris.target

# %%
# now we'll use 'train_test_split' from sklearn to split the data into training and testing sets
test_size = 0.3  # cold also specify 'train_size=0.7' instead
random_state = 0

# 'train_test_split' convenience function
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

# %%
# standardize the data like we did before, but use the
# 'StandardScaler' from sklearn

sc = StandardScaler()

# fit the scaler to the training feature set only
sc.fit(X_train)

# scale (transform) the training AND the testing sets using the
# scaler that was fitted to training data
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# it is important to transform non-numeric target values into numbers
# prior to splitting the data to avoid unexpected results when modeling
print(f"Unique labels: {np.unique(y)}")
# Out:
# Unique labels: [0 1 2]

# %%
# we will select a subset of the features as before
X_train_std = X_train_std[:, [2, 3]]
X_test_std = X_test_std[:, [2, 3]]

# %%
# train a model using sklearn's implementation of the perceptron
n_iter = 40
eta0 = 0.1

# create the perceptron instance
ppn = Perceptron(n_iter_no_change=n_iter, eta0=eta0, random_state=random_state)

# fit model to standardized data
ppn.fit(X_train_std, y_train)

# make a prediction
y_pred = ppn.predict(X_test_std)

# %% [markdown]
# we can measure performance using the 'accuracy_score' convenience function in sklearn

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred)*100}")
# Out:
# Accuracy: 95.55555555555556

# %% [markdown]
# Let's add some functionality to our 'plot_decision_regions' convenience function by highlighting the test samples on our plot

# %%
def plot_decision_regions(X, y, classifier, resolution=0.2, test_idx=None):
    """Convenience function for visualizing decision boundaries"""
    # setup marker genearot and clolr map
    # this can handle multi-class plotting
    markers = ("s", "x", "o", "^", "v")
    colors = ("red", "blue", "lightgreen", "gray", "cyan")
    cmap = ListedColormap(colors[: len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min(), X[:, 0].max()
    x2_min, x2_max = X[:, 1].min(), X[:, 1].max()
    xx1, xx2 = np.meshgrid(
        np.arange(x1_min, x1_max, resolution),
        np.arange(x2_min, x2_max, resolution),
    )

    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)

    Z = Z.reshape(xx1.shape)
    plt.figure()
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)

    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # plot the class samples
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(
            x=X[y == cl, 0],
            y=X[y == cl, 1],
            alpha=0.8,
            color=cmap(idx),
            marker=markers[idx],
            label=cl,
        )

    ### NEW CODE ######################################
    if test_idx:
        X_test, y_test = X[test_idx, :], y[test_idx]
        plt.scatter(
            X_test[:, 0],
            X_test[:, 1],
            facecolors="none",
            edgecolors="black",
            alpha=1.0,
            linewidths=1,
            marker="o",
            s=65,
            label="test set",
        )

# %% [markdown]
# With those modications in place, we can specify the test indices. First we need to re-combine the training and testing datasets

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))

y_combined = np.hstack((y_train, y_test))

# plot the decision regions
X = X_combined_std
y = y_combined

test_idx = range(105, 150)
plot_decision_regions(X=X, y=y, classifier=ppn, test_idx=test_idx)

# format the labels and legend
plt.xlabel("petal length [standardized]")
plt.ylabel("petal width [standardized]")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Logistic Regression in sklearn

# %% [markdown]
# ### The logistic function
# The inverse form of the logit function (a.k.a sigmoid funciton)

# %%
def sigmoid(z):
    """Return sigmoid values from net input.

    z is the net input or linear combination of the
    weights and features (like from before)
    """
    return 1.0 / (1.0 + np.exp(-z))

# %% [markdown]
# Plot the sigmoid to get a better sense of it's properties

# %%
z = np.arange(-7, 7, 0.1)

phi_z = sigmoid(z)

plt.plot(z, sigmoid(z))

plt.axvline(0.0, color="k")
plt.axhspan(0.0, 1.0, facecolor="1.0", alpha=1.0, ls="dotted")
plt.axhline(y=0.5, ls="dotted", color="k")
plt.yticks([0, 0.5, 1])
plt.ylim(-0.1, 1.1)
plt.xlabel("z")
plt.ylabel("$\phi (z)$")
# Out:
# Text(0, 0.5, '$\\phi (z)$')

# %% [markdown]
# ### Model with the logistic regression algorithm from sklearn

# %%
from sklearn.linear_model import LogisticRegression

# %%
# params
C = 1000.0
random_state = 0
lr = LogisticRegression(C=C, random_state=random_state)

# fit the model
lr.fit(X_train_std, y_train)
# Out:
# LogisticRegression(C=1000.0, random_state=0)

# %%
# plot the decision regions

# use the combined datasets and the same test indices as above
plot_decision_regions(X=X, y=y, classifier=lr, test_idx=test_idx)

# format the labels and legend
plt.xlabel("petal length [standardized]")
plt.ylabel("petal width [standardized]")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Predicting Class Probabilities
#
# We can also return probabilities that our sampls belong to each of the classes with logistic regression in sklearn
#
# As of sklearn 0.17, we need to resahpe the data since predictions are only made on a single sample

# %%
test_sample = X_test_std[0, :].copy().reshape(1, -1)

probs = lr.predict_proba(test_sample)

# iris species dict
iris_labels_dict = {0: "Setosa", 1: "Versicolor", 2: "Virginica"}

class_name = iris_labels_dict
class_number = lr.classes_  # access the classes attribute of our lr
probability = probs[0]  # 'probs' is a nested array once probs are predicted

print("Probability this sample belongs to each class: ")
for i, _ in enumerate(lr.classes_):
    print(f"{class_name[i]} [{class_number[i]}: {probability[i] * 100}")
# Out:
# Probability this sample belongs to each class:
# Setosa [0: 99.99629125398963
# Versicolor [1: 0.0037087460103721282
# Virginica [2: 3.145799741038821e-18

# %% [markdown]
# We can look at how differnt values of 'C' effect the regularization strength of the model -->> smaller values of 'C' == more regularization

# %%
weights, params = [], []
for c in np.arange(-5, 5):
    C = 10.0**c
    lr = LogisticRegression(C=C, random_state=0)
    lr.fit(X_train_std, y_train)
    weights.append(lr.coef_[1])
    params.append(C)

weights = np.array(weights)
plt.plot(params, weights[:, 0], label="petal length")
plt.plot(params, weights[:, 1], label="petal width")
plt.xlabel("C")
plt.ylabel("weight coefficient")
plt.legend(loc="upper left")
plt.title("Regularization Strength for Different Values of 'C'")
plt.xscale("log")

# %% [markdown]
# ## Training Support Vector Machines (SVM) in sklearn

# %%
from sklearn.svm import SVC

# create the svm instance
kernel = "linear"

svm = SVC(kernel=kernel, C=1.0, random_state=0)

# fit model
svm.fit(X_train_std, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
# plot the results
X = X_combined_std
y = y_combined
plot_decision_regions(X_combined_std, y_combined, classifier=svm, test_idx=test_idx)

plt.xlabel("petal length [standardized]")
plt.ylabel("petal width [standardized]")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Solving Non-linear Problems with Kernel SVM

# %% [markdown]
# #### We need to create a non-linear dataset

# %%
np.random.seed(0)
X_xor = np.random.randn(200, 2)
y_xor = np.logical_xor(X_xor[:, 0] > 0, X_xor[:, 1] > 0)
y_xor = np.where(np.logical_xor(X_xor[:, 0] > 0, X_xor[:, 1] > 0), 1, -1)

# plot the first class
plt.scatter(
    X_xor[y_xor == 1, 0],
    X_xor[y_xor == 1, 1],
    c="blue",
    marker="x",
    label=1,
)

# plot the second class
plt.scatter(
    X_xor[y_xor == -1, 0],
    X_xor[y_xor == -1, 1],
    c="red",
    marker="s",
    label=-1,
)

plt.ylim(-3.0)
plt.legend(loc="upper left")

# %% [markdown]
# ### SVM Kernel Trick

# %% [markdown]
# Train the svm using the kernel trickh (higher gamma == softer decision boundary). This parameter effects the influence or reach of training samples

# %%
svm = SVC(kernel="rbf", random_state=0, gamma=0.1, C=10)  # radial basis function kernel

svm.fit(X_xor, y_xor)
# Out:
# SVC(C=10, gamma=0.1, random_state=0)

# %%
plot_decision_regions(X=X_xor, y=y_xor, classifier=svm)
plt.legend(loc="upper left")

# %% [markdown]
# ## The effect of Gamma
#
# Attempt to gain some intuition ab out the effect of gamma using the iris dataset

# %%
# create the svm instance
svm = SVC(kernel="rbf", random_state=0, gamma=0.2, C=1.0)

# fit the model
svm.fit(X_train_std, y_train)
# Out:
# SVC(gamma=0.2, random_state=0)

# %%
# plot the decision regions
plot_decision_regions(X_combined_std, y_combined, classifier=svm, test_idx=test_idx)
plt.xlabel("petal length [standardized]")
plt.ylabel("petal width [standardized]")
plt.legend(loc="upper left")

# %% [markdown]
# Now increase the value of gamma from 0.2 -->> 100.0 and observe the effect on the decision boundary

# %%
# create the svm instance
svm = SVC(kernel="rbf", random_state=0, gamma=100.0, C=1.0)

# fit the model
svm.fit(X_train_std, y_train)

# plot the decision regions
plot_decision_regions(X_combined_std, y_combined, classifier=svm, test_idx=test_idx)
plt.xlabel("petal length [standardized]")
plt.ylabel("petal width [standardized]")
plt.legend(loc="upper left")

# %% [markdown]
# ## Decision Trees in sklearn
# ### Training with decision trees
#
# Decision trees in sklearn can have different splitting criteria:
# - entropy (lower is better): Intuition is that it is a purity metric
# - classification error (lower is better)
# - gini (higher is better): can be thought of as minimizing the classification error

# %%
def gini(p):
    return p * (1 - p) + (1 - p) * (1 - (1 - p))


def entropy(p):
    return -p * np.log2(p) - (1 - p) * np.log2(1 - p)


def error(p):
    return 1 - np.max([p, 1 - p])


x = np.arange(0, 1.0, 0.01)
ent = [entropy(p) if p != 0 else None for p in x]
sc_ent = [e * 0.5 if e else None for e in ent]
err = [error(i) for i in x]

criterion = [ent, sc_ent, gini(x), err]
labels = ["Entropy", "Entropy (scaled", "Gini Impurity", "Misclassification Error"]
linestyles = ["-", "-", "--", "-."]
colors = ["black", "lightgray", "red", "green", "cyan"]

fig = plt.figure()
ax = plt.subplot(111)
for i, lab, ls, c in zip(criterion, labels, linestyles, colors):
    line = ax.plot(x, i, label=lab, linestyle=ls, lw=2, color=c)

ax.legend(
    loc="upper center", bbox_to_anchor=(0.5, 1.15), ncol=3, fancybox=True, shadow=False
)

ax.axhline(y=0.5, linewidth=1, color="k", linestyle="--")

ax.axhline(y=1.0, linewidth=1, color="k", linestyle="--")

plt.ylim([0, 1.1])
plt.xlabel("p(i=1)")
plt.ylabel("Impurity Index")
# Out:
# Text(0, 0.5, 'Impurity Index')

# %% [markdown]
# ### Training a Decision Tree
#
# Non-standardized data can be used for decision tree models. They are known as non-parametric models.
#
# Standardized data can be used for cleaner charts at a later time if desired, but are not a requirment of the model.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X_train = X_train[:, [2, 3]]
X_test = X_test[:, [2, 3]]

# create the tree instance
tree = DecisionTreeClassifier(criterion="entropy", max_depth=3, random_state=0)

# fit the model
tree.fit(X_train, y_train)

# re-combine the data for plotting
X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))

# plot the results
plot_decision_regions(X_combined, y_combined, classifier=tree, test_idx=test_idx)

plt.xlabel("petal length [cm]")
plt.ylabel("petal width [cm]")
plt.legend(loc="upper left")

# %% [markdown]
# Scikit learn also offers ensamble methods such as random forests which are an ensamble of multiple weak learners that are combined to form a more robust model that has lower generalization error and is less susceptable to over-fitting.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# create the tree instance
forest = RandomForestClassifier(
    criterion="entropy",
    max_depth=3,
    random_state=0,
    n_jobs=2,  # number of cpus to use for modeling. Use -1 to use all
    # n_estimators=10,  # number of trees to include int he forest
)

# fit the model
forest.fit(X_train, y_train)

# plot decision_regions
plot_decision_regions(X_combined, y_combined, classifier=forest, test_idx=test_idx)

plt.xlabel("petal length [cm]")
plt.ylabel("petal width [cm]")
plt.legend(loc="upper left")

# %% [markdown]
# ### Lazy learning with the k-nearest neighbors (knn) classifier.
#
# KNN doesn't actually learn from the data, it just memorizes the training data. Then the user chooses the number of `k` and some kind of distance metric. The algorithm then finds the `k` nearest neighbors of the sample that is to be classified and takes a majority vote to assign the label for the predicted point
#
# the distance metric is encoded as:
# - 1 == 'manhattan'
# - 2 == 'euclidean'
#
# It will be important to use standardized data b/c we are using a distance metric.
#
# KNN classifiers have almost 0 cost to train the model because it is only memorizing the data, but the model will become increasingly difficult to store because it will store all data used in the prediction.

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create the knn instance
knn = KNeighborsClassifier(n_neighbors=5, p=2, metric="minkowski")  # euclidean

# fit the model
knn.fit(X_train_std, y_train)

# plot decision_regions
plot_decision_regions(X_combined_std, y_combined, classifier=knn, test_idx=test_idx)

plt.xlabel("petal length [standardized]")
plt.ylabel("petal width [standardized]")
plt.legend(loc="upper left")
